# %%
from google.colab import drive

# %%
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import random
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.preprocessing.image import ImageDataGenerator,array_to_img,img_to_array
# %matplotlib inline
from matplotlib import pyplot as plt
import cv2

# %%
datagen = ImageDataGenerator(
     width_shift_range = 0.2)

# %%
imgs = os.listdir('/content/drive/My Drive/Colab Notebooks/tmp/train/normal/')

# %%
for img in imgs:
    img=cv2.imread('/content/drive/My Drive/Colab Notebooks/tmp/train/normal/'+"//"+img)
    x = img_to_array(img)
    x = x.reshape((1,) + x.shape)  

    i = 0
    for batch in datagen.flow (x, batch_size=1, save_to_dir ='/content/drive/MyDrive/Colab Notebooks/tmp/width shift/normal', save_prefix ='width shift', save_format='jpg'):
        i+=1
        if i>1:
            break
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-26-daad959d0a39> in <module>()
#       1 for img in imgs:
#       2     img=cv2.imread('/content/drive/My Drive/Colab Notebooks/tmp/train/normal/'+"//"+img)
# ----> 3     x = img_to_array(img)
#       4     x = x.reshape((1,) + x.shape)
#       5
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/preprocessing/image.py in img_to_array(img, data_format, dtype)
#     230       dtype = backend.floatx()
#     231     kwargs['dtype'] = dtype
# --> 232   return image.img_to_array(img, data_format=data_format, **kwargs)
#     233
#     234
#
# /usr/local/lib/python3.7/dist-packages/keras_preprocessing/image/utils.py in img_to_array(img, data_format, dtype)
#     317             x = x.reshape((x.shape[0], x.shape[1], 1))
#     318     else:
# ...
