# %%
from google.colab import drive

# %%
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import random
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.preprocessing.image import ImageDataGenerator,array_to_img,img_to_array
# %matplotlib inline
from matplotlib import pyplot as plt
import cv2

# %%
datagen = ImageDataGenerator(
     horizontal_flip=True)

# %%
imgs = os.listdir('/content/drive/My Drive/Colab Notebooks/tmp/train/potholes/')

# %%
for img in imgs:
    img=cv2.imread('/content/drive/My Drive/Colab Notebooks/tmp/train/potholes/'+"//"+img)
    x = img_to_array(img)
    x = x.reshape((1,) + x.shape)  

    i = 0
    for batch in datagen.flow (x, batch_size=1, save_to_dir ='/content/drive/MyDrive/Colab Notebooks/tmp/horizontal flip', save_prefix ='zoom', save_format='jpg'):
        i+=1
        if i>2:
            break
